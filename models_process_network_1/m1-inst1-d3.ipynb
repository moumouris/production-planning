# %%
import gurobipy as gp
from gurobipy import GRB
import numpy as np
import sys
sys.path.append('../classes/')
print(sys.path)
from model1 import Model

#Constants we are going to use
total_weeks = 8
hours_in_week = 24 * 7
hours_in_day = 24
delivery_interval = 7 #days
Dt = 6 #hours

#Model sets
tasks = ['T11', 'T12', 'T21', 'T22', 'T31', 'T32', 'T41', 'T42', 'T43', 'T51', 'T52']
units = ['U1', 'U2', 'U3', 'U4', 'U5']
time_points = [i for i in range(int(total_weeks * hours_in_week / Dt) + 1)]
time_periods = [i for i in range(1, int(total_weeks * hours_in_week / Dt) + 1)]
materials = ['RM1', 'RM2', 'INT1', 'INT2', 'INT3', 'INT4', 'A', 'B1', 'B2', 'C1', 'C2']

#Model parameters
capacities = [80, 80, 5, 5, 5, 5, 10, 10, 10, 10, 10] #materials
production_costs = [1.0, 1.0, 0.5, 0.5, 1.5, 1.5, 1.0, 0.5, 0.5, 1.0, 0.5] #tasks
storage_costs = [0, 0, 0, 0, 0, 0, 1.5, 1.4, 1.8, 1.2, 2.0] #materials
daily_production_rate = [2, 1, 1, 1, 2, 2, 2, 1, 1, 1, 1] #tasks
production_rate = [rate for rate in daily_production_rate]
onhand_inventory_list = [ 80, 80, 0, 0, 0, 0, 0, 0, 0, 0, 0]

key_value_pairs_storage_cost = zip(materials, storage_costs)
key_value_pairs_production_cost = zip(tasks, production_costs)
key_value_pairs_capacity = zip(materials, capacities)
key_value_pairs_production_rate = zip(tasks, production_rate)
key_value_pairs_onhand_inventory = zip(materials, onhand_inventory_list)

material_storage_cost = dict(key_value_pairs_storage_cost)
task_production_cost = dict(key_value_pairs_production_cost)
capacity = dict(key_value_pairs_capacity)
task_daily_production_rate = dict(key_value_pairs_production_rate)
onhand_inventory = dict(key_value_pairs_onhand_inventory)

unit_can_process_tasks = {
  'U1': ['T11', 'T12'],
  'U2': ['T21', 'T22'],
  'U3': ['T31', 'T32'],
  'U4': ['T41', 'T42', 'T43'],
  'U5': ['T51', 'T52']
}

material_produced_by_tasks = {
  'RM1': [],
  'RM2': [],
  'INT1': ['T11', 'T21'],
  'INT2': ['T12', 'T22'],
  'INT3': ['T31'],
  'INT4': ['T32'],
  'A': ['T41'],
  'B1': ['T42'],
  'B2': ['T51'],
  'C1': ['T43'],
  'C2': ['T52']
}

material_consumed_by_tasks = {
  'RM1': ['T11', 'T21'],
  'RM2': ['T12', 'T22'],
  'INT1': ['T31', 'T41'],
  'INT2': ['T32'],
  'INT3': ['T42', 'T51'],
  'INT4': ['T43', 'T52'],
  'A': [],
  'B1': [],
  'B2': [],
  'C1': [],
  'C2': []
}

net_delivery = {}
for k in materials:
  for n in time_points:
    net_delivery[(k,n)] = 0

fp_deliveries_string = "3.0 2.5 3.5 2.5 2.5\
                        3.5 3.0 3.0 2.0 3.5\
                        2.5 2.5 2.5 1.0 1.5\
                        3.0 2.0 3.0 2.0 3.0\
                        1.5 2.0 1.5 0.5 3.0\
                        2.5 3.0 3.0 2.5 2.0\
                        4.0 0.0 1.0 2.0 1.5\
                        3.0 2.5 2.5 2.0 1.5"

fp_deliveries = np.array([-float(x) for x in fp_deliveries_string.split()])
fp_deliveries = fp_deliveries.reshape(8, 5)

for i, k in enumerate(materials[6:]):
  for j, n in enumerate(range(int(delivery_interval * (24 / Dt)), time_points[-1] + 1, int(delivery_interval * (24 / Dt)))):
    net_delivery[(k,n)] = fp_deliveries[j][i]

network_data = [tasks, materials, units, unit_can_process_tasks, material_consumed_by_tasks, material_produced_by_tasks]

network = {}
network['tasks']                      = tasks
network['materials']                  = materials
network['units']                      = units
network['unit_can_process_tasks']     = unit_can_process_tasks
network['material_consumed_by_tasks'] = material_consumed_by_tasks
network['material_produced_by_tasks'] = material_produced_by_tasks

parameters = {}
parameters['material_storage_cost']      = material_storage_cost
parameters['task_production_cost']       = task_production_cost
parameters['task_daily_production_rate'] = task_daily_production_rate
parameters['Dt']                         = Dt
parameters['onhand_inventory']           = onhand_inventory
parameters['net_delivery']               = net_delivery
parameters['capacity']                   = capacity
parameters['days_duration']              = 56

print(task_daily_production_rate.values())
model = Model(network, parameters)
# Out:
# ['c:\\Users\\amoum\\Documents\\διπλωματικη\\models_process_network_1', 'c:\\Python310\\python310.zip', 'c:\\Python310\\DLLs', 'c:\\Python310\\lib', 'c:\\Python310', '', 'C:\\Users\\amoum\\AppData\\Roaming\\Python\\Python310\\site-packages', 'C:\\Users\\amoum\\AppData\\Roaming\\Python\\Python310\\site-packages\\win32', 'C:\\Users\\amoum\\AppData\\Roaming\\Python\\Python310\\site-packages\\win32\\lib', 'C:\\Users\\amoum\\AppData\\Roaming\\Python\\Python310\\site-packages\\Pythonwin', 'c:\\Python310\\lib\\site-packages', '..', 'c:\\Users\\amoum\\Documents\\διπλωματικη\\classes', 'c:\\Users\\amoum\\Documents\\διπλωματικη\\classes', '../classes/', '../classes/', '../classes/', '../classes/', '../classes/', '../classes/', '../classes/', '../classes/', '../classes/']
# dict_values([2, 1, 1, 1, 2, 2, 2, 1, 1, 1, 1])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\amoum\Documents\διπλωματικη\models_process_network_1\m1-inst1-d3.ipynb Cell 1 line <cell line: 121>()
#     <a href='vscode-notebook-cell:/c%3A/Users/amoum/Documents/%CE%B4%CE%B9%CF%80%CE%BB%CF%89%CE%BC%CE%B1%CF%84%CE%B9%CE%BA%CE%B7/models_process_network_1/m1-inst1-d3.ipynb#W0sZmlsZQ%3D%3D?line=117'>118</a> parameters['days_duration']              = 56
#     <a href='vscode-notebook-cell:/c%3A/Users/amoum/Documents/%CE%B4%CE%B9%CF%80%CE%BB%CF%89%CE%BC%CE%B1%CF%84%CE%B9%CE%BA%CE%B7/models_process_network_1/m1-inst1-d3.ipynb#W0sZmlsZQ%3D%3D?line=119'>120</a> print(task_daily_production_rate.values())
# --> <a href='vscode-notebook-cell:/c%3A/Users/amoum/Documents/%CE%B4%CE%B9%CF%80%CE%BB%CF%89%CE%BC%CE%B1%CF%84%CE%B9%CE%BA%CE%B7/models_process_network_1/m1-inst1-d3.ipynb#W0sZmlsZQ%3D%3D?line=120'>121</a> model = Model(network, parameters)
#
# File c:\Users\amoum\Documents\διπλωματικη\classes\model1.py:15, in Model.__init__(self, network, network_parameters, name)
#      13 self.m = gp.Model(name)
#      14 self.w, self.w_s, self.s = self._addModelVars()
# ---> 15 self._addModelConstraints()
#      16 self._setObjective()
#      17 self._optimize()
#
# File c:\Users\amoum\Documents\διπλωματικη\classes\model1.py:37, in Model._addModelConstraints(self)
#      35 material_consumed_by_tasks = self.network['material_consumed_by_tasks']
#      36 capacities                 = self.parameters['capacity']
# ---> 37 task_production_rates      = self.parameters['task_daily_production_rate'] * (24 / self.parameters['Dt'])
#      38 onhand_inventory           = self.parameters['onhand_inventory']
#      39 net_delivery               = self.parameters['net_delivery']
#
# TypeError: unsupported operand type(s) for *: 'dict' and 'float'
